# %%
losses = [ 0.172658,
0.140202, 
0.132086,
0.121411,
0.125710,
0.126822,
0.108595,
0.111065,
0.112157,
0.108502,
0.109179,
0.103206,
0.104152,
0.106249,
0.101621]

# %%
import matplotlib.pyplot as plt

# %%
data = [0.172658, 0.140202, 0.132086, 0.121411, 0.125710, 0.126822, 0.108595, 0.111065, 0.112157, 0.108502, 0.109179, 0.103206, 0.104152, 0.106249, 0.101621]
indices = list(range(1, len(data) + 1))  # Creating a list of integers from 1 to the length of the data

plt.plot(indices, data, marker='o', linestyle='-', color='b')
plt.title('MSE Loss, 100,000 samples')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
